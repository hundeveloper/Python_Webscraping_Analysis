# %%
# %pip show requests
# Out:
# Name: requests
# Version: 2.32.3
# Summary: Python HTTP for Humans.
# Home-page: https://requests.readthedocs.io
# Author: Kenneth Reitz
# Author-email: me@kennethreitz.org
# License: Apache-2.0
# Location: C:\Users\hun\anaconda3\Lib\site-packages
# Requires: certifi, charset-normalizer, idna, urllib3
# Required-by: aext-assistant-server, anaconda-catalogs, anaconda-client, anaconda-cloud-auth, anaconda-project, conda, conda-build, conda-repo-cli, conda_package_streaming, cookiecutter, datashader, jupyterlab_server, panel, requests-file, requests-toolbelt, Sphinx, streamlit, tldextract
# Note: you may need to restart the kernel to use updated packages.

# %%
# %pip show beautifulsoup4
# Out:
# Name: beautifulsoup4
# Version: 4.12.3
# Summary: Screen-scraping library
# Home-page: https://www.crummy.com/software/BeautifulSoup/bs4/
# Author:
# Author-email: Leonard Richardson <leonardr@segfault.org>
# License: MIT License
# Location: C:\Users\hun\anaconda3\Lib\site-packages
# Requires: soupsieve
# Required-by: conda-build, nbconvert
# Note: you may need to restart the kernel to use updated packages.

# %%
# reqeusts, bs4 import
import requests
import bs4
# BeautifulSoup 클래스 import
from bs4 import BeautifulSoup

# %%
# requests, bs4 버전 확인하기
print(f'requests 버전 {requests.__version__}')
print(f'beautifulsoup4 버전 {bs4.__version__}')
# Out:
# requests 버전 2.32.3
# beautifulsoup4 버전 4.12.3

# %%
import requests
from bs4 import BeautifulSoup

# IT/과학 뉴스
req_param = {
    'sid': 105
}

# Naver 뉴스 IT/과학 섹션 URL
url = 'https://news.naver.com/section/{sid}'.format(**req_param)

print("요청 URL:", url)

# 요청 헤더 설정 : 브라우저 정보 흉내내기
req_header = {
    'User-Agent': 'Mozilla/5.0 (Windows NT 10.0; Win64; x64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/123.0.0.0 Safari/537.36'
}

# GET 요청 보내기
response = requests.get(url, headers=req_header)

# 응답 확인
if response.status_code == 200:
    # 응답에서 HTML 추출
    html = response.text

    # BeautifulSoup 객체 생성
    soup = BeautifulSoup(html, 'html.parser')

    # 뉴스 링크 찾기 (모바일 뉴스 article 링크 포함된 <a> 태그들)
    links = soup.select("div.sa_text a[href*='mnews/article']")
    
    # 결과 출력
    for link in links:
        print(link.text.strip())
        print("기사 링크:", link['href'])
        print('-' * 40)
else:
    print("요청 실패, 상태코드:", response.status_code)
# Out:
# 요청 URL: https://news.naver.com/section/105
# 우주항공청, 주요국과 동맹 가속…“공동 연구개발 단초 마련”
# 기사 링크: https://n.news.naver.com/mnews/article/138/0002194241
# ----------------------------------------
#
# 기사 링크: https://n.news.naver.com/mnews/article/comment/138/0002194241
# ----------------------------------------
# 기업은행 SKT와 손잡고, 보이스피싱 AI로 실시간 탐지한다
# 기사 링크: https://n.news.naver.com/mnews/article/025/0003432668
# ----------------------------------------
#
# 기사 링크: https://n.news.naver.com/mnews/article/comment/025/0003432668
# ----------------------------------------
# 카카오메이커스, 누적 거래액 1조원 돌파
# 기사 링크: https://n.news.naver.com/mnews/article/001/0015317219
# ----------------------------------------
#
# 기사 링크: https://n.news.naver.com/mnews/article/comment/001/0015317219
# ----------------------------------------
# 카메라로 옷 보여주면 코디까지…삼성 갤럭시S25, '비주얼 AI' 업데이트
# 기사 링크: https://n.news.naver.com/mnews/article/030/0003301022
# ----------------------------------------
#
# 기사 링크: https://n.news.naver.com/mnews/article/comment/030/0003301022
# ----------------------------------------
# 스미싱 문자 발송 사전 차단…국민 불편·재산 피해 최소화
# 기사 링크: https://n.news.naver.com/mnews/article/421/0008179948
# ----------------------------------------
#
# 기사 링크: https://n.news.naver.com/mnews/article/comment/421/0008179948
# ----------------------------------------
# 신세계I&C 수장된 양윤지, 국내외 리테일 테크 AX 시장 노리고 新무기 공개
# 기사 링크: https://n.news.naver.com/mnews/article/092/0002369810
# ----------------------------------------
#
# 기사 링크: https://n.news.naver.com/mnews/article/comment/092/0002369810
# ----------------------------------------
# 뤼튼 "개인화 서비스로 AI의 생활화, 1인 1AI 시대 열 것"
# 기사 링크: https://n.news.naver.com/mnews/article/277/0005574566
# ----------------------------------------
#
# 기사 링크: https://n.news.naver.com/mnews/article/comment/277/0005574566
# ----------------------------------------
# "역시 믿을 건 갤럭시"...'갤S25 흥행' 삼성 모바일, 나홀로 선방
# 기사 링크: https://n.news.naver.com/mnews/article/008/0005177299
# ----------------------------------------
#
# 기사 링크: https://n.news.naver.com/mnews/article/comment/008/0005177299
# ----------------------------------------
# [이슈플러스]삼성전자 1분기 메모리 실적 '선방'
# 기사 링크: https://n.news.naver.com/mnews/article/030/0003301404
# ----------------------------------------
#
# 기사 링크: https://n.news.naver.com/mnews/article/comment/030/0003301404
# ----------------------------------------
# 소액주주 눈높이 맞춘다…한화에어로, 유증 3.6조→2.3조 축소
# 기사 링크: https://n.news.naver.com/mnews/article/092/0002369838
# ----------------------------------------
#
# 기사 링크: https://n.news.naver.com/mnews/article/comment/092/0002369838
# ----------------------------------------
# 의협 "작년 2월 전으로 돌아가야"…정부·국회에 대화 요구(종합)
# 기사 링크: https://n.news.naver.com/mnews/article/421/0008180782
# ----------------------------------------
#
# 기사 링크: https://n.news.naver.com/mnews/article/comment/421/0008180782
# ----------------------------------------
# 한화오션, 차세대 드릴십 인도…심해 시추 본격 진출
# 기사 링크: https://n.news.naver.com/mnews/article/092/0002369836
# ----------------------------------------
#
# 기사 링크: https://n.news.naver.com/mnews/article/comment/092/0002369836
# ----------------------------------------
# “보여주면 알아서 설명” 삼성, 갤럭시 S25에 ‘실시간 비주얼 AI’ 도입
# 기사 링크: https://n.news.naver.com/mnews/article/018/0005982544
# ----------------------------------------
#
# 기사 링크: https://n.news.naver.com/mnews/article/comment/018/0005982544
# ----------------------------------------
# "5G 투자회수도 멀었는데"…글로벌 통신업계 '6G' 회의론
# 기사 링크: https://n.news.naver.com/mnews/article/008/0005177554
# ----------------------------------------
#
# 기사 링크: https://n.news.naver.com/mnews/article/comment/008/0005177554
# ----------------------------------------
# 삼성 1분기 실적 효자는 '갤S25'…2Q '슬림' 판매량 관건
# 기사 링크: https://n.news.naver.com/mnews/article/014/0005332970
# ----------------------------------------
#
# 기사 링크: https://n.news.naver.com/mnews/article/comment/014/0005332970
# ----------------------------------------
# 영화 'HER' 속 사만사처럼…뤼튼의 '1인 1AI' 전략
# 기사 링크: https://n.news.naver.com/mnews/article/648/0000035139
# ----------------------------------------
#
# 기사 링크: https://n.news.naver.com/mnews/article/comment/648/0000035139
# ----------------------------------------
# [현장] "AI, 이제 도구가 아닌 친구"…뤼튼, '1인 1AI' 시대 연다
# 기사 링크: https://n.news.naver.com/mnews/article/092/0002369831
# ----------------------------------------
#
# 기사 링크: https://n.news.naver.com/mnews/article/comment/092/0002369831
# ----------------------------------------
# 의협 “내년 정원 확정해달라…교육 불가능땐 모집인원 줄여야”
# 기사 링크: https://n.news.naver.com/mnews/article/029/0002946712
# ----------------------------------------
#
# 기사 링크: https://n.news.naver.com/mnews/article/comment/029/0002946712
# ----------------------------------------
# “자문인줄 알았는데” 리멤버, 전직 직원에 내부정보 요구 논란
# 기사 링크: https://n.news.naver.com/mnews/article/018/0005982502
# ----------------------------------------
#
# 기사 링크: https://n.news.naver.com/mnews/article/comment/018/0005982502
# ----------------------------------------
# 리플 "전 세계 금융 시장, 실물자산 토큰화 중심으로 근본 변화"
# 기사 링크: https://n.news.naver.com/mnews/article/092/0002369827
# ----------------------------------------
#
# 기사 링크: https://n.news.naver.com/mnews/article/comment/092/0002369827
# ----------------------------------------
# 당뇨·비만 치료제가 치매 위험 33~43% 낮춘다
# 기사 링크: https://n.news.naver.com/mnews/article/366/0001067652
# ----------------------------------------
#
# 기사 링크: https://n.news.naver.com/mnews/article/comment/366/0001067652
# ----------------------------------------
# 과기정통부·KISA, 스팸문자 사전 차단 '엑스레이 서비스' 시범 도입
# 기사 링크: https://n.news.naver.com/mnews/article/366/0001067651
# ----------------------------------------
#
# 기사 링크: https://n.news.naver.com/mnews/article/comment/366/0001067651
# ----------------------------------------
# 에이비엘바이오, '4조 기술이전' 후 첫 공식석상…로드맵 밝힌다
# 기사 링크: https://n.news.naver.com/mnews/article/421/0008180569
# ----------------------------------------
#
# 기사 링크: https://n.news.naver.com/mnews/article/comment/421/0008180569
# ----------------------------------------
# 한국계 NASA 우주인 조니 김 태운 러 우주선, ISS로 발사
# 기사 링크: https://n.news.naver.com/mnews/article/023/0003898288
# ----------------------------------------
#
# 기사 링크: https://n.news.naver.com/mnews/article/comment/023/0003898288
# ----------------------------------------
# “韓 AI 선진국 위해 'AI기술'보다 데이터 확보가 필요”
# 기사 링크: https://n.news.naver.com/mnews/article/030/0003301377
# ----------------------------------------
#
# 기사 링크: https://n.news.naver.com/mnews/article/comment/030/0003301377
# ----------------------------------------
# ISMS-P 인증 뭐기에…의무도 아닌데, 하겠단 금융사
# 기사 링크: https://n.news.naver.com/mnews/article/092/0002369826
# ----------------------------------------
#
# 기사 링크: https://n.news.naver.com/mnews/article/comment/092/0002369826
# ----------------------------------------
# "의료계 제안 논의하자"…의협, 정부·국회에 '대화의 장' 요구
# 기사 링크: https://n.news.naver.com/mnews/article/421/0008180565
# ----------------------------------------
#
# 기사 링크: https://n.news.naver.com/mnews/article/comment/421/0008180565
# ----------------------------------------
# 질병청-녹십자 개발 '탄저백신' 품목허가 "백신주권 확립"
# 기사 링크: https://n.news.naver.com/mnews/article/014/0005332936
# ----------------------------------------
#
# 기사 링크: https://n.news.naver.com/mnews/article/comment/014/0005332936
# ----------------------------------------
# 항암제 피하는 암세포 꼼수 발견…악성 폐암도 잡는다
# 기사 링크: https://n.news.naver.com/mnews/article/081/0003531724
# ----------------------------------------
#
# 기사 링크: https://n.news.naver.com/mnews/article/comment/081/0003531724
# ----------------------------------------
# 뤼튼 "무료전략으로 생활형 AI 시대 열 것…올해 천만 MAU 목표"
# 기사 링크: https://n.news.naver.com/mnews/article/421/0008180537
# ----------------------------------------
#
# 기사 링크: https://n.news.naver.com/mnews/article/comment/421/0008180537
# ----------------------------------------
# 첫 한국계 ‘NASA 우주비행사’ 조니 김, 마침내 지구 궤도로 떠났다
# 기사 링크: https://n.news.naver.com/mnews/article/032/0003361993
# ----------------------------------------
#
# 기사 링크: https://n.news.naver.com/mnews/article/comment/032/0003361993
# ----------------------------------------
# 질병청, 세계 첫 단백질 재조합 탄저백신 '배리트락스' 상용화
# 기사 링크: https://n.news.naver.com/mnews/article/015/0005116525
# ----------------------------------------
#
# 기사 링크: https://n.news.naver.com/mnews/article/comment/015/0005116525
# ----------------------------------------
# 트럼프 관세, 세계경제 큰 타격…美中 충돌로 더 증폭
# 기사 링크: https://n.news.naver.com/mnews/article/092/0002369818
# ----------------------------------------
#
# 기사 링크: https://n.news.naver.com/mnews/article/comment/092/0002369818
# ----------------------------------------
# [100세 과학] 노년 건강 유지엔 채식보다 육식
# 기사 링크: https://n.news.naver.com/mnews/article/366/0001067643
# ----------------------------------------
#
# 기사 링크: https://n.news.naver.com/mnews/article/comment/366/0001067643
# ----------------------------------------
# [사고]스테이블코인 vs CBDC…디지털금융 대세는 어디로?
# 기사 링크: https://n.news.naver.com/mnews/article/018/0005982461
# ----------------------------------------
#
# 기사 링크: https://n.news.naver.com/mnews/article/comment/018/0005982461
# ----------------------------------------
# 폐암 면역치료 새 전략 찾았다…면역항암 막는 핵심인자 최초로 발견
# 기사 링크: https://n.news.naver.com/mnews/article/021/0002701758
# ----------------------------------------
#
# 기사 링크: https://n.news.naver.com/mnews/article/comment/021/0002701758
# ----------------------------------------
# "갤럭시S26 울트라, 카메라 사양 등 전작과 큰 변화 없다"
# 기사 링크: https://n.news.naver.com/mnews/article/092/0002369817
# ----------------------------------------
#
# 기사 링크: https://n.news.naver.com/mnews/article/comment/092/0002369817
# ----------------------------------------
# 구영배 "위시 살려야" 주장에 피해자들 분통…"차라리 처벌 받아라"
# 기사 링크: https://n.news.naver.com/mnews/article/092/0002369816
# ----------------------------------------
#
# 기사 링크: https://n.news.naver.com/mnews/article/comment/092/0002369816
# ----------------------------------------
# 관세 폭탄에 스마트폰 공장 美로 옮긴다?…"가능성 희박"
# 기사 링크: https://n.news.naver.com/mnews/article/092/0002369815
# ----------------------------------------
#
# 기사 링크: https://n.news.naver.com/mnews/article/comment/092/0002369815
# ----------------------------------------
# 전국에 딱 500대만 풀린다…'한정판 갤럭시S25'의 정체
# 기사 링크: https://n.news.naver.com/mnews/article/015/0005116508
# ----------------------------------------
#
# 기사 링크: https://n.news.naver.com/mnews/article/comment/015/0005116508
# ----------------------------------------
# [6G 코리아] ④ 이통3사, AI-RAN 시장 개척 주도
# 기사 링크: https://n.news.naver.com/mnews/article/030/0003301337
# ----------------------------------------
#
# 기사 링크: https://n.news.naver.com/mnews/article/comment/030/0003301337
# ----------------------------------------
# 한바이오 "모유두세포로 탈모 정복하겠다"
# 기사 링크: https://n.news.naver.com/mnews/article/015/0005116502
# ----------------------------------------
#
# 기사 링크: https://n.news.naver.com/mnews/article/comment/015/0005116502
# ----------------------------------------
# 뤼튼, 감정 교류도 하는 'AI 비서' 낸다
# 기사 링크: https://n.news.naver.com/mnews/article/293/0000065879
# ----------------------------------------
#
# 기사 링크: https://n.news.naver.com/mnews/article/comment/293/0000065879
# ----------------------------------------
# 온라인서 예금토큰 결제 지연…9일부터 순차적으로 진행
# 기사 링크: https://n.news.naver.com/mnews/article/092/0002369813
# ----------------------------------------
#
# 기사 링크: https://n.news.naver.com/mnews/article/comment/092/0002369813
# ----------------------------------------

# %%
import requests
from bs4 import BeautifulSoup

section_dict = {
    100: '정치',
    101: '경제',
    102: '사회',
    103: '생활/문화',
    104: '세계',
    105: 'IT/과학'
}

def print_news(sid, section):  # 예: print_news(103, '생활/문화')
    print(f"📢 [{section}] 뉴스 목록")
    print('-' * 40)

    url = f'https://news.naver.com/section/{sid}'

    headers = {
        'User-Agent': 'Mozilla/5.0 (Windows NT 10.0; Win64; x64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/123.0.0.0 Safari/537.36'
    }

    response = requests.get(url, headers=headers)

    if response.status_code == 200:
        soup = BeautifulSoup(response.text, 'html.parser')
        links = soup.select("div.sa_text a[href*='mnews/article']")

        for link in links[:5]:  # 상위 5개만 출력
            print(link.text.strip())
            print("링크:", link['href'])
            print('-' * 30)
    else:
        print("❌ 요청 실패:", response.status_code)

# 함수 호출
print_news(100, section_dict[103])
# Out:
# 📢 [생활/문화] 뉴스 목록
# ----------------------------------------
# 간소한 영상 출마 선언한 이재명…‘세 과시’ 대선 나선 한동훈
# 링크: https://n.news.naver.com/mnews/article/018/0005984468
# ------------------------------
#
# 링크: https://n.news.naver.com/mnews/article/comment/018/0005984468
# ------------------------------
# 원희룡 전 장관, 대선 불출마 "대통령 탄핵 저에게도 큰 책임"
# 링크: https://n.news.naver.com/mnews/article/008/0005178366
# ------------------------------
#
# 링크: https://n.news.naver.com/mnews/article/comment/008/0005178366
# ------------------------------
# 이재명 32%·김문수 12%…정권 교체 48%·정권 재창출 37%[NBS]
# 링크: https://n.news.naver.com/mnews/article/020/0003627365
# ------------------------------
