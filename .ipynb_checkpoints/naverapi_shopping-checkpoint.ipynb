# %%
pip install requests python-dotenv
# Out:
# Requirement already satisfied: requests in c:\users\hun\anaconda3\lib\site-packages (2.32.3)
# Requirement already satisfied: python-dotenv in c:\users\hun\anaconda3\lib\site-packages (0.21.0)
# Requirement already satisfied: charset-normalizer<4,>=2 in c:\users\hun\anaconda3\lib\site-packages (from requests) (3.3.2)
# Requirement already satisfied: idna<4,>=2.5 in c:\users\hun\anaconda3\lib\site-packages (from requests) (3.7)
# Requirement already satisfied: urllib3<3,>=1.21.1 in c:\users\hun\anaconda3\lib\site-packages (from requests) (2.2.3)
# Requirement already satisfied: certifi>=2017.4.17 in c:\users\hun\anaconda3\lib\site-packages (from requests) (2025.1.31)
# Note: you may need to restart the kernel to use updated packages.

# %%
#3-1 질문

import requests
import os
from dotenv import load_dotenv

# .env 파일에서 환경 변수 로드
load_dotenv()
NAVER_CLIENT_ID = os.getenv("NAVER_CLIENT_ID")
NAVER_CLIENT_SECRET = os.getenv("NAVER_CLIENT_SECRET")

# 공통 헤더 설정
headers = {
    "X-Naver-Client-Id": NAVER_CLIENT_ID,
    "X-Naver-Client-Secret": NAVER_CLIENT_SECRET
}

# 쇼핑 아이템 출력 함수
def print_shop_item(idx, item):
    title = item['title'].replace('<b>', '').replace('</b>', '')
    lprice = f"{int(item['lprice']):,}원"
    brand = item.get('brand', '').strip()
    mall = item.get('mallName', '').strip()
    link = item['link']

    print(f"{idx}. {title}")
    print(f"   최저가: {lprice}")
    print(f"   브랜드: {brand}")
    print(f"   쇼핑몰: {mall}")
    print(f"   링크: {link}")
    print()

# 쇼핑 검색 함수
def search_shops(query):
    url = "https://openapi.naver.com/v1/search/shop.json"
    payload = {
        "query": query,
        "display": 10,  # 최대 100개 가능
        "sort": "sim"
    }

    res = requests.get(url, headers=headers, params=payload)
    if res.status_code == 200:
        items = res.json().get('items', [])
        if items:
            print("=== 쇼핑 검색 결과 ===\n")
            for idx, item in enumerate(items, 1):
                print_shop_item(idx, item)
        else:
            print("검색 결과가 없습니다.")
    else:
        print(f"API 호출 실패: {res.status_code}")
        print("응답 메시지:", res.text)

# 예시 실행
search_shops("가디건")
# Out:
# === 쇼핑 검색 결과 ===
#
# 1. 백화점3-5일배송 폴로 가디건 걸즈 걸스 랄프로렌 꽈배기 블랙 화이트 핑크 헌터네이비XL
#    최저가: 64,900원
#    브랜드: 폴로랄프로렌
#    쇼핑몰: 나우인뉴욕
#    링크: https://smartstore.naver.com/main/products/6672150068
#
# 2. 봄 가을 간절기 라운드 루즈핏 크롭 가디건 레드 그린 핑크 화이트 블랙 옐로우
#    최저가: 19,900원
#    브랜드:
#    쇼핑몰: ARUMY
#    링크: https://smartstore.naver.com/main/products/5466947569
#
# 3. 부드러운 캐시미어 크롭 가디건 숏 라운드 니트가디건 여성 가디건 봄 간절기 레드 핑크
#    최저가: 18,900원
#    브랜드:
#    쇼핑몰: 코이블리
#    링크: https://smartstore.naver.com/main/products/4828155463
#
# 4. [백화점3-5일배송] 폴로 가디건 니트 걸즈 랄프로렌 블랙 화이트 핑크 헌터네이비XL L
#    최저가: 63,900원
#    브랜드: 폴로랄프로렌
#    쇼핑몰: 트위티 155
#    링크: https://smartstore.naver.com/main/products/8450462001
#
# 5. [국내발송 + 선물포장] 폴로 랄프로렌 여아 아기 코튼 베이비 가디건 핑크 옐로우 화이트
#    최저가: 69,000원
#    브랜드: 폴로랄프로렌
#    쇼핑몰: 리틀데이즈
#    링크: https://smartstore.naver.com/main/products/9459545518
#
# 6. 10COLOR 여성 봄 비비드컬러 라운드 슬릿넥 크롭 니트 그린 핑크가디건
#    최저가: 24,900원
#    브랜드:
#    쇼핑몰: ARUMY
#    링크: https://smartstore.naver.com/main/products/9959540751
#
# 7. [백화점] 폴로 가디건 걸즈 케이블 꽈배기 니트
#    최저가: 69,000원
#    브랜드: 폴로랄프로렌
#    쇼핑몰: 세컨찬스라이프
#    링크: https://smartstore.naver.com/main/products/11107384300
#
# 8. 꼼데가르송 기본와펜 가디건 여성용
#    최저가: 254,390원
#    브랜드: 꼼데가르송
#    쇼핑몰: 레이바쿠
#    링크: https://smartstore.naver.com/main/products/4741606965
#
# 9. 제너럴아이디어 WOMAN GNRL 에센셜 베이직 카디건 11COL WBD3L04503
#    최저가: 33,600원
#    브랜드: 제너럴아이디어
#    쇼핑몰: 네이버
#    링크: https://search.shopping.naver.com/catalog/53287208769
#
# 10. 메종키츠네 가디건 베이비폭스 폭스헤드 더블폭스 칠랙스 [당일출고]
#    최저가: 267,000원
#    브랜드: 메종키츠네
#    쇼핑몰: 브랜드리퍼블릭
#    링크: https://smartstore.naver.com/main/products/5302659122

# %%
#3-2 질문

import requests
import os
from dotenv import load_dotenv

# .env 파일에서 환경 변수 로드
load_dotenv()
NAVER_CLIENT_ID = os.getenv("NAVER_CLIENT_ID")
NAVER_CLIENT_SECRET = os.getenv("NAVER_CLIENT_SECRET")

# 공통 헤더 설정
headers = {
    "X-Naver-Client-Id": NAVER_CLIENT_ID,
    "X-Naver-Client-Secret": NAVER_CLIENT_SECRET
}

# 쇼핑 아이템 출력 함수
def print_shop_item(idx, item):
    title = item['title'].replace('<b>', '').replace('</b>', '')
    lprice = f"{int(item['lprice']):,}원"
    brand = item.get('brand', '').strip()
    mall = item.get('mallName', '').strip()
    link = item['link']

    print(f"{idx}. {title}")
    print(f"   최저가: {lprice}")
    print(f"   브랜드: {brand}")
    print(f"   쇼핑몰: {mall}")
    print(f"   링크: {link}")
    print()

# 가격 조건 필터링 후 출력
def search_shops_under_price(query, max_price):
    url = "https://openapi.naver.com/v1/search/shop.json"
    payload = {
        "query": query,
        "display": 3,
        "sort": "sim"
    }

    res = requests.get(url, headers=headers, params=payload)
    if res.status_code == 200:
        items = res.json().get('items', [])
        filtered_items = [item for item in items if int(item['lprice']) <= max_price]

        if filtered_items:
            print(f"=== {max_price:,}원 이하 상품 ===\n")
            for idx, item in enumerate(filtered_items, 1):
                print_shop_item(idx, item)
        else:
            print(f"{max_price:,}원 이하 상품이 없습니다.")
    else:
        print(f"API 호출 실패: {res.status_code}")
        print("응답 메시지:", res.text)

# 예시 실행
search_shops_under_price("가디건", 50000)
# Out:
# === 50,000원 이하 상품 ===
#
# 1. 봄 가을 간절기 라운드 루즈핏 크롭 가디건 레드 그린 핑크 화이트 블랙 옐로우
#    최저가: 19,900원
#    브랜드:
#    쇼핑몰: ARUMY
#    링크: https://smartstore.naver.com/main/products/5466947569
#
# 2. 부드러운 캐시미어 크롭 가디건 숏 라운드 니트가디건 여성 가디건 봄 간절기 레드 핑크
#    최저가: 18,900원
#    브랜드:
#    쇼핑몰: 코이블리
#    링크: https://smartstore.naver.com/main/products/4828155463

# %%
import requests
import os
import re
from dotenv import load_dotenv

# .env 파일에서 환경 변수 로드
load_dotenv()
NAVER_CLIENT_ID = os.getenv("NAVER_CLIENT_ID")
NAVER_CLIENT_SECRET = os.getenv("NAVER_CLIENT_SECRET")

# 공통 헤더
headers = {
    "X-Naver-Client-Id": NAVER_CLIENT_ID,
    "X-Naver-Client-Secret": NAVER_CLIENT_SECRET
}

# 쇼핑 검색 결과 출력 함수
def print_shop_item(idx, item):
    title = re.sub(r"<.*?>", "", item.get("title", ""))
    lprice = int(item.get("lprice", 0))
    brand = item.get("brand", "").strip()
    mall = item.get("mallName", "").strip()
    link = item.get("link", "").strip()

    print(f"{idx}. {title}")
    print(f"   최저가: {lprice:,}원")
    print(f"   브랜드: {brand}")
    print(f"   쇼핑몰: {mall}")
    print(f"   링크: {link}\n")

# 특정 쇼핑몰 상품만 검색
def search_shops_by_mall(query, mall_name):
    url = "https://openapi.naver.com/v1/search/shop.json"
    all_filtered_items = []
    display = 30
    start = 1
    total_to_fetch = 200  # 최대 200개까지 조회 (2페이지)

    while start < total_to_fetch:
        payload = {
            "query": query,
            "display": display,
            "start": start,
            "sort": "sim"
        }

        res = requests.get(url, headers=headers, params=payload)
        if res.status_code != 200:
            print(f"API 호출 실패: {res.status_code}")
            break

        items = res.json().get("items", [])
        if not items:
            break

        # 쇼핑몰 필터링
        filtered = [item for item in items if item.get("mallName", "").strip() == mall_name]
        all_filtered_items.extend(filtered)

        start += display

    # 결과 출력
    if all_filtered_items:
        print(f"=== {mall_name} 상품 목록 ({len(all_filtered_items)}개) ===\n")
        for idx, item in enumerate(all_filtered_items, 1):
            print_shop_item(idx, item)
    else:
        print(f"{mall_name} 상품이 없습니다.")

# 사용 예시
search_shops_by_mall("가디건", "네이버")
# Out:
# === 네이버 상품 목록 (100개) ===
#
# 1. 제너럴아이디어 WOMAN GNRL 에센셜 베이직 카디건 11COL WBD3L04503
#    최저가: 33,600원
#    브랜드: 제너럴아이디어
#    쇼핑몰: 네이버
#    링크: https://search.shopping.naver.com/catalog/53287208769
#
# 2. H&amp;M HM 파인 니트 가디건 0579541001
#    최저가: 17,512원
#    브랜드: H&M
#    쇼핑몰: 네이버
#    링크: https://search.shopping.naver.com/catalog/51781610172
#
# 3. 벤시몽 여성 코튼 블렌드 케이블 가디건 3종
#    최저가: 44,910원
#    브랜드: 벤시몽
#    쇼핑몰: 네이버
#    링크: https://search.shopping.naver.com/catalog/53232763110
#
# 4. 리스트 라운드넥 버튼 니트 가디건 TSKCDO72010
#    최저가: 23,000원
#    브랜드: 리스트
#    쇼핑몰: 네이버
#    링크: https://search.shopping.naver.com/catalog/51143733510
#
# 5. 제너럴아이디어 GENERALIDEA WOMAN 에센셜 크루넥 가디건 4COL WBD3L04501
#    최저가: 31,416원
#    브랜드: 제너럴아이디어
#    쇼핑몰: 네이버
#    링크: https://search.shopping.naver.com/catalog/49541497760
#
# 6. 라코스테 남성 베이직 V넥 방모 가디건 AH560E-54N
#    최저가: 80,100원
#    브랜드: 라코스테
#    쇼핑몰: 네이버
#    링크: https://search.shopping.naver.com/catalog/49714141886
#
# 7. 비비안웨스트우드 여성 베아 울 실크 가디건 1803001Z
#    최저가: 23,840원
#    브랜드: 비비안웨스트우드
#    쇼핑몰: 네이버
#    링크: https://search.shopping.naver.com/catalog/43475137325
#
# 8. 벤시몽 여성 케이블 니트 가디건 3종
#    최저가: 37,650원
#    브랜드: 벤시몽
#    쇼핑몰: 네이버
#    링크: https://search.shopping.naver.com/catalog/53373694627
#
# 9. 쉬즈미스 메탈 라운드넥 니트 가디건 SSKCDO31060
#    최저가: 36,910원
#    브랜드: 쉬즈미스
#    쇼핑몰: 네이버
#    링크: https://search.shopping.naver.com/catalog/49625464649
#
# 10. 라코스테 남성 피케 조직 V넥 울가디건 AH697E-54N
#    최저가: 167,440원
#    브랜드: 라코스테
#    쇼핑몰: 네이버
#    링크: https://search.shopping.naver.com/catalog/50705955349
#
# 11. 셀렙샵에디션 알파카 캔디 니트가디건
#    최저가: 53,900원
#    브랜드: 셀렙샵에디션
#    쇼핑몰: 네이버
#    링크: https://search.shopping.naver.com/catalog/53020866519
#
# 12. 모르간 24FW 반팔 울 니트가디건 3종 88
#    최저가: 37,160원
#    브랜드: 모르간
#    쇼핑몰: 네이버
#    링크: https://search.shopping.naver.com/catalog/50504636053
#
# 13. 톰브라운 남성 가디건 415 MJT167A 00535
#    최저가: 671,030원
#    브랜드: 톰브라운
#    쇼핑몰: 네이버
#    링크: https://search.shopping.naver.com/catalog/52101774528
#
# 14. 폴햄 여성 자켓형 가디건 PHF1EC2030
#    최저가: 29,900원
#    브랜드: 폴햄
#    쇼핑몰: 네이버
#    링크: https://search.shopping.naver.com/catalog/51964323969
#
# 15. 제너럴아이디어 제너럴 아이디어 WOMAN 멀티 스트라이프 크루넥 가디건 남색 NA WBE1L04504NA
#    최저가: 32,472원
#    브랜드: 제너럴아이디어
#    쇼핑몰: 네이버
#    링크: https://search.shopping.naver.com/catalog/52384299518
#
# 16. 라코스테 여성 케이블 크루넥 가디건 AF091E-54N
#    최저가: 143,100원
#    브랜드: 라코스테
#    쇼핑몰: 네이버
#    링크: https://search.shopping.naver.com/catalog/49912758699
#
# 17. LE TROIS 23FW 르투아 투웨이 니트 집업 카라 가디건 2종 세트
#    최저가: 13,100원
#    브랜드:
#    쇼핑몰: 네이버
#    링크: https://search.shopping.naver.com/catalog/53690259105
#
# 18. 리스트 라운드넥 루즈핏 가디건 TSKCDO72520
#    최저가: 24,280원
#    브랜드: 리스트
#    쇼핑몰: 네이버
#    링크: https://search.shopping.naver.com/catalog/49580876217
#
# 19. 미쏘 에센셜 브이넥 베이직 가디건 MIWCKE920T
#    최저가: 11,690원
#    브랜드: 미쏘
#    쇼핑몰: 네이버
#    링크: https://search.shopping.naver.com/catalog/49441291447
#
# 20. 제이슨우 Spring 가디건 3종
#    최저가: 74,310원
#    브랜드: 제이슨우
#    쇼핑몰: 네이버
#    링크: https://search.shopping.naver.com/catalog/52482107751
#
# 21. 리스트 리스트 아웃 포켓 크롭 가디건 TSKCDO70030
#    최저가: 24,020원
#    브랜드: 리스트
#    쇼핑몰: 네이버
#    링크: https://search.shopping.naver.com/catalog/51690622371
#
# 22. 스파오 라운드넥 카디건 SPCKF23W01
#    최저가: 25,848원
#    브랜드: 스파오
#    쇼핑몰: 네이버
#    링크: https://search.shopping.naver.com/catalog/51659066776
#
# 23. 로엠 브이넥 가디건 RMCKF23R98
#    최저가: 44,910원
#    브랜드: 로엠
#    쇼핑몰: 네이버
#    링크: https://search.shopping.naver.com/catalog/52675721484
#
# 24. 폴로랄프로렌 폴로 랄프로렌 여성 코튼 블렌드 가디건
#    최저가: 125,400원
#    브랜드: 폴로랄프로렌
#    쇼핑몰: 네이버
#    링크: https://search.shopping.naver.com/catalog/45723735727
#
# 25. 아미 AMI 스몰 하트 남성 울 가디건 491 HKC001 001
#    최저가: 279,000원
#    브랜드: 아미
#    쇼핑몰: 네이버
#    링크: https://search.shopping.naver.com/catalog/50931741210
#
# 26. 베네통스포츠 베네통스포츠 여성 니트 가디건 2종
#    최저가: 85,980원
#    브랜드:
#    쇼핑몰: 네이버
#    링크: https://search.shopping.naver.com/catalog/53126962083
#
# 27. 타미힐피거 여성 라운드 넥 버튼 다운 긴팔 가디건 4색
#    최저가: 59,900원
#    브랜드: 타미힐피거
#    쇼핑몰: 네이버
#    링크: https://search.shopping.naver.com/catalog/40804917010
#
# 28. BNX 캐릭터 자수 포인트 버튼업 니트 가디건 BW3CD009L0
#    최저가: 15,065원
#    브랜드: BNX
#    쇼핑몰: 네이버
#    링크: https://search.shopping.naver.com/catalog/52483360456
#
# 29. 제너럴아이디어 WOMAN 시그니처 슈퍼파인 울 케이블 가디건 4COL WBD3L04505
#    최저가: 31,000원
#    브랜드: 제너럴아이디어
#    쇼핑몰: 네이버
#    링크: https://search.shopping.naver.com/catalog/52131507480
#
# 30. 아울렛상품 올리브데올리브 올리브데올리브 시스루 브이넥 니트 가디건 YK4AD706
#    최저가: 24,900원
#    브랜드: 올리브데올리브
#    쇼핑몰: 네이버
#    링크: https://search.shopping.naver.com/catalog/52752095274
#
# 31. 메종키츠네 여성 더블 폭스 헤드 가디건 H250 GW00544KT1036
#    최저가: 126,300원
#    브랜드: 메종키츠네
#    쇼핑몰: 네이버
#    링크: https://search.shopping.naver.com/catalog/50703782063
#
# 32. 타미힐피거 여성 라운드넥 케이블 가디건
#    최저가: 56,910원
#    브랜드: 타미힐피거
#    쇼핑몰: 네이버
#    링크: https://search.shopping.naver.com/catalog/50798194985
#
# 33. 사색 블루아 V 파인울 랩 가디건
#    최저가: 49,700원
#    브랜드: 사색
#    쇼핑몰: 네이버
#    링크: https://search.shopping.naver.com/catalog/52525143696
#
# 34. 사색 젤라 크롭트 슬림 가디건
#    최저가: 37,800원
#    브랜드: 사색
#    쇼핑몰: 네이버
#    링크: https://search.shopping.naver.com/catalog/53568688511
#
# 35. G-CUT 지컷 스팽글 브이넥 크롭 가디건 7254450301
#    최저가: 85,960원
#    브랜드: 지컷
#    쇼핑몰: 네이버
#    링크: https://search.shopping.naver.com/catalog/53494485754
#
# 36. 쉬즈미스 글리터 펀칭 브이넥 가디건 SSKCDO11080
#    최저가: 30,830원
#    브랜드: 쉬즈미스
#    쇼핑몰: 네이버
#    링크: https://search.shopping.naver.com/catalog/52523460806
#
# 37. 스파오 소프트얀 케이블 라운드넥 카디건 SPCKE49W11
#    최저가: 15,900원
#    브랜드: 스파오
#    쇼핑몰: 네이버
#    링크: https://search.shopping.naver.com/catalog/49686421611
#
# 38. 폴로 여성 피마 코튼 가디건
#    최저가: 74,610원
#    브랜드:
#    쇼핑몰: 네이버
#    링크: https://search.shopping.naver.com/catalog/53042166323
#
# 39. 게스 게스진 SUZY 여성 데님믹스 입체격자 스웨터 가디건 YP1S2660
#    최저가: 137,260원
#    브랜드: 게스
#    쇼핑몰: 네이버
#    링크: https://search.shopping.naver.com/catalog/53319519216
#
# 40. 후아유 스티브 케이블 가디건 WHCKE4901F
#    최저가: 27,810원
#    브랜드: 후아유
#    쇼핑몰: 네이버
#    링크: https://search.shopping.naver.com/catalog/49715176984
#
# 41. 라삐아프 도톰 가디건 3종
#    최저가: 65,010원
#    브랜드: 라삐아프
#    쇼핑몰: 네이버
#    링크: https://search.shopping.naver.com/catalog/52482116627
#
# 42. 지오다노 NEW 여자 면 혼방 꽈배기 버튼 가디건 355504
#    최저가: 30,880원
#    브랜드: 지오다노
#    쇼핑몰: 네이버
#    링크: https://search.shopping.naver.com/catalog/52507346449
#
# 43. 올리브데올리브 슬림핏 브이넥 가디건 YK5SD417
#    최저가: 33,200원
#    브랜드: 올리브데올리브
#    쇼핑몰: 네이버
#    링크: https://search.shopping.naver.com/catalog/52662970843
#
# 44. 써스데이아일랜드 멀티 날개사 니트 가디건 T252MCD132W
#    최저가: 112,028원
#    브랜드: 써스데이아일랜드
#    쇼핑몰: 네이버
#    링크: https://search.shopping.naver.com/catalog/53287693121
#
# 45. 폴로랄프로렌 걸즈 케이블 꽈배기 가디건
#    최저가: 52,120원
#    브랜드: 폴로랄프로렌
#    쇼핑몰: 네이버
#    링크: https://search.shopping.naver.com/catalog/50507277915
#
# 46. 쉬즈미스 글리터 라운드넥 가디건 SSKCDO31080
#    최저가: 39,200원
#    브랜드: 쉬즈미스
#    쇼핑몰: 네이버
#    링크: https://search.shopping.naver.com/catalog/51018804569
#
# 47. 제너럴아이디어 WOMAN GNRL 에센셜 가디건 WBD3L04503RE
#    최저가: 29,568원
#    브랜드: 제너럴아이디어
#    쇼핑몰: 네이버
#    링크: https://search.shopping.naver.com/catalog/53551244510
#
# 48. 타미힐피거 여성 케이블 니트 프론트 버튼 가디건
#    최저가: 38,100원
#    브랜드: 타미힐피거
#    쇼핑몰: 네이버
#    링크: https://search.shopping.naver.com/catalog/51555556692
#
# 49. 리스트 투웨이 집업 가디건 TSKCDO72540
#    최저가: 29,000원
#    브랜드: 리스트
#    쇼핑몰: 네이버
#    링크: https://search.shopping.naver.com/catalog/49686701880
#
# 50. 베네통스포츠 썸머 컬러풀 가디건 2종 여성용
#    최저가: 125,120원
#    브랜드:
#    쇼핑몰: 네이버
#    링크: https://search.shopping.naver.com/catalog/53807225971
#
# 51. 플라스틱아일랜드 버튼 포인트 니트 가디건 PQTKG097
#    최저가: 16,130원
#    브랜드: 플라스틱아일랜드
#    쇼핑몰: 네이버
#    링크: https://search.shopping.naver.com/catalog/51692292034
#
# 52. 탑텐 여성 프리미엄 화인 메리노 가디건 MSF2EC2801
#    최저가: 29,900원
#    브랜드: 탑텐
#    쇼핑몰: 네이버
#    링크: https://search.shopping.naver.com/catalog/51979177083
#
# 53. 제너럴아이디어 텐셀 에센셜 하프 가디건 4COL WBD2L04527
#    최저가: 20,944원
#    브랜드: 제너럴아이디어
#    쇼핑몰: 네이버
#    링크: https://search.shopping.naver.com/catalog/46838632664
#
# 54. 리스트 골지 브이넥 니트 가디건 TSKCDN70020
#    최저가: 22,000원
#    브랜드: 리스트
#    쇼핑몰: 네이버
#    링크: https://search.shopping.naver.com/catalog/41494988614
#
# 55. The AtG 더엣지 24FW 버튼업 니트 3종
#    최저가: 45,035원
#    브랜드: 더엣지
#    쇼핑몰: 네이버
#    링크: https://search.shopping.naver.com/catalog/52675874133
#
# 56. 제너럴아이디어 WOMAN 텐셀 브이넥 케이블 가디건 WBD2L43545
#    최저가: 35,280원
#    브랜드: 제너럴아이디어
#    쇼핑몰: 네이버
#    링크: https://search.shopping.naver.com/catalog/49473925791
#
# 57. 지오지아 남성 소프트 터치 집업 가디건 AEE4EC1101
#    최저가: 39,900원
#    브랜드: 지오지아
#    쇼핑몰: 네이버
#    링크: https://search.shopping.naver.com/catalog/51264062255
#
# 58. 제너럴아이디어 GENERALIDEA WOMAN 시그니처 브이넥 케이블 가디건 3COL WBE1L04509
#    최저가: 37,102원
#    브랜드: 제너럴아이디어
#    쇼핑몰: 네이버
#    링크: https://search.shopping.naver.com/catalog/53126734906
#
# 59. 제너럴아이디어 GENERALIDEA WOMAN 에센셜 카라 레이어드 가디건 3COL WBD3L04524
#    최저가: 35,156원
#    브랜드: 제너럴아이디어
#    쇼핑몰: 네이버
#    링크: https://search.shopping.naver.com/catalog/51343595335
#
# 60. 쉬즈미스 트위드 라운드 반팔 가디건 SSKCDO22560
#    최저가: 37,050원
#    브랜드: 쉬즈미스
#    쇼핑몰: 네이버
#    링크: https://search.shopping.naver.com/catalog/50723236565
#
# 61. 리스트 스트라이프 니트 가디건 TSKCDN70030
#    최저가: 29,000원
#    브랜드: 리스트
#    쇼핑몰: 네이버
#    링크: https://search.shopping.naver.com/catalog/41837614906
#
# 62. H&amp;M HM 공식브랜드관 파인 니트 가디건 크림색 0579541072
#    최저가: 17,512원
#    브랜드: H&M
#    쇼핑몰: 네이버
#    링크: https://search.shopping.naver.com/catalog/51721127435
#
# 63. 로엠 올데이 라운드넥 가디건 RMCKF23R99
#    최저가: 44,910원
#    브랜드: 로엠
#    쇼핑몰: 네이버
#    링크: https://search.shopping.naver.com/catalog/52675590914
#
# 64. 까사렐 밀라노 니트 보머자켓 3종
#    최저가: 47,400원
#    브랜드: 까사렐
#    쇼핑몰: 네이버
#    링크: https://search.shopping.naver.com/catalog/52821868693
#
# 65. BNX 컬러 버튼업 자수 라운드넥 니트 가디건 BW4CD013L0
#    최저가: 19,096원
#    브랜드: BNX
#    쇼핑몰: 네이버
#    링크: https://search.shopping.naver.com/catalog/50797937031
#
# 66. BNX 캐쥬얼 심플 투웨이 후드집업 가디건 BW4CD032L0
#    최저가: 24,579원
#    브랜드: BNX
#    쇼핑몰: 네이버
#    링크: https://search.shopping.naver.com/catalog/51183115094
#
# 67. 몽돌 9 24 골지 브이넥 가디건 MDCD034
#    최저가: 22,425원
#    브랜드: 몽돌
#    쇼핑몰: 네이버
#    링크: https://search.shopping.naver.com/catalog/50082342013
#
# 68. 써스데이아일랜드 테입사 케이블 니트 가디건 T252MCD134W
#    최저가: 86,076원
#    브랜드: 써스데이아일랜드
#    쇼핑몰: 네이버
#    링크: https://search.shopping.naver.com/catalog/53269489286
#
# 69. 폴햄 남성 코숏 면 피케 가디건 PHE1TC1210
#    최저가: 26,010원
#    브랜드: 폴햄
#    쇼핑몰: 네이버
#    링크: https://search.shopping.naver.com/catalog/45147084338
#
# 70. 온앤온 스트라이프 가디건 NEK3XD831
#    최저가: 88,950원
#    브랜드: 온앤온
#    쇼핑몰: 네이버
#    링크: https://search.shopping.naver.com/catalog/34508265631
#
# 71. 탑텐 공용 에코 테리 후드 집업 MSF5TC3901
#    최저가: 23,310원
#    브랜드: 탑텐
#    쇼핑몰: 네이버
#    링크: https://search.shopping.naver.com/catalog/52178080819
#
# 72. 아가방 봄 나나니트가디건 01Q155001
#    최저가: 12,700원
#    브랜드: 아가방
#    쇼핑몰: 네이버
#    링크: https://search.shopping.naver.com/catalog/52193264942
#
# 73. 노스페이스키즈 키즈 스쿨데이 가디건 NJ5JP01
#    최저가: 37,390원
#    브랜드: 노스페이스키즈
#    쇼핑몰: 네이버
#    링크: https://search.shopping.naver.com/catalog/47680403486
#
# 74. 여성 이중배색 가디건 레이어드 부드러운 루즈핏 울니트 가을 겨울 간절기 캐주얼 오피스 TS829
#    최저가: 16,150원
#    브랜드:
#    쇼핑몰: 네이버
#    링크: https://search.shopping.naver.com/catalog/54001079624
#
# 75. 에고이스트 Label 하트버튼 포인트 퍼프 가디건 ER2OKG01
#    최저가: 62,550원
#    브랜드: 에고이스트
#    쇼핑몰: 네이버
#    링크: https://search.shopping.naver.com/catalog/53267457732
#
# 76. 라코스테 여성 25SS링스 가디건 AF5631-55G166
#    최저가: 233,100원
#    브랜드: 라코스테
#    쇼핑몰: 네이버
#    링크: https://search.shopping.naver.com/catalog/52925012030
#
# 77. 라코스테 베이직 V넥 가디건 AH5665 54N 031
#    최저가: 169,470원
#    브랜드: 라코스테
#    쇼핑몰: 네이버
#    링크: https://search.shopping.naver.com/catalog/50993070619
#
# 78. 탑텐 남성 사선 조직 가디건 MSE1EC1901
#    최저가: 19,500원
#    브랜드: 탑텐
#    쇼핑몰: 네이버
#    링크: https://search.shopping.naver.com/catalog/45195190658
#
# 79. 폴햄 덤블 플리스 집업 가디건 1종 여성용
#    최저가: 35,910원
#    브랜드: 폴햄
#    쇼핑몰: 네이버
#    링크: https://search.shopping.naver.com/catalog/52163719148
#
# 80. 반에이크 페리니트가디건 VB52KCM302Z
#    최저가: 18,340원
#    브랜드: 반에이크
#    쇼핑몰: 네이버
#    링크: https://search.shopping.naver.com/catalog/52727527032
#
# 81. 베네통 자수 니트 가디건 BAKC09341
#    최저가: 129,150원
#    브랜드: 베네통
#    쇼핑몰: 네이버
#    링크: https://search.shopping.naver.com/catalog/49831145874
#
# 82. 라코스테 남성 케이블 집업 가디건 AH302E-54N
#    최저가: 201,720원
#    브랜드: 라코스테
#    쇼핑몰: 네이버
#    링크: https://search.shopping.naver.com/catalog/50371554628
#
# 83. 지고트 여성 가디건 숄 카라넥 봄 캐주얼
#    최저가: 72,090원
#    브랜드: 지고트
#    쇼핑몰: 네이버
#    링크: https://search.shopping.naver.com/catalog/52540616299
#
# 84. 잇미샤 라운드넥 컬러믹스 가디건 ITP2ZCD700
#    최저가: 78,948원
#    브랜드: 잇미샤
#    쇼핑몰: 네이버
#    링크: https://search.shopping.naver.com/catalog/52614366666
#
# 85. 미쏘 에센셜 라운드넥 베이직 가디건 MIWCKE910T
#    최저가: 11,690원
#    브랜드: 미쏘
#    쇼핑몰: 네이버
#    링크: https://search.shopping.naver.com/catalog/49441337074
#
# 86. M12 여성 크로셰 후드집업 1종
#    최저가: 61,512원
#    브랜드:
#    쇼핑몰: 네이버
#    링크: https://search.shopping.naver.com/catalog/53808979546
#
# 87. 파인 니트 가디건 0579541185
#    최저가: 19,900원
#    브랜드:
#    쇼핑몰: 네이버
#    링크: https://search.shopping.naver.com/catalog/53126965431
#
# 88. 타미힐피거 여성 미니 플래그 로고 라운드넥 베이직 버튼업 가디건
#    최저가: 49,900원
#    브랜드: 타미힐피거
#    쇼핑몰: 네이버
#    링크: https://search.shopping.naver.com/catalog/40152397835
#
# 89. 스티브 케이블 가디건 WHCKF2101F
#    최저가: 36,820원
#    브랜드:
#    쇼핑몰: 네이버
#    링크: https://search.shopping.naver.com/catalog/53878043969
#
# 90. 제너럴아이디어 WOMAN 텐셀 리브드 카라 가디건 2COL WBE1L04525
#    최저가: 36,000원
#    브랜드: 제너럴아이디어
#    쇼핑몰: 네이버
#    링크: https://search.shopping.naver.com/catalog/53395789804
#
# 91. 스튜디오톰보이 라운드넥 베이직 가디건 9194451822
#    최저가: 87,710원
#    브랜드: 스튜디오톰보이
#    쇼핑몰: 네이버
#    링크: https://search.shopping.naver.com/catalog/47985981640
#
# 92. 탑텐 여성 코튼 블렌드 자켓 재킷 가디건 MSF1EC2101
#    최저가: 29,302원
#    브랜드: 탑텐
#    쇼핑몰: 네이버
#    링크: https://search.shopping.naver.com/catalog/52284391747
#
# 93. 지컷 브이넥 케이블 가디건 7254350103
#    최저가: 93,240원
#    브랜드: 지컷
#    쇼핑몰: 네이버
#    링크: https://search.shopping.naver.com/catalog/50777406232
#
# 94. 리스트 코튼 메탈 버튼 가디건 TSKCDN70050
#    최저가: 29,000원
#    브랜드: 리스트
#    쇼핑몰: 네이버
#    링크: https://search.shopping.naver.com/catalog/41475421959
#
# 95. 벤시몽 여성 케이블 가디건 라벤더 S B1061
#    최저가: 27,210원
#    브랜드:
#    쇼핑몰: 네이버
#    링크: https://search.shopping.naver.com/catalog/51829767762
#
# 96. 지스튜디오 실크혼방 옴브레 트윙클 가디건
#    최저가: 89,100원
#    브랜드: 지스튜디오
#    쇼핑몰: 네이버
#    링크: https://search.shopping.naver.com/catalog/52876243877
#
# 97. 프로젝트엠 남성 베이직 Y넥 가디건 EPD4EC1100
#    최저가: 13,980원
#    브랜드: 프로젝트엠
#    쇼핑몰: 네이버
#    링크: https://search.shopping.naver.com/catalog/52908956587
#
# 98. GGPX 카라넥 데님 배색 금장 버튼 케이블 긴팔 가디건 GODCK009D
#    최저가: 17,556원
#    브랜드: GGPX
#    쇼핑몰: 네이버
#    링크: https://search.shopping.naver.com/catalog/51124415166
#
# 99. 셀렙샵에디션 셀렙샵 에디션 24FW 모헤어 클라우드 가디건
#    최저가: 33,357원
#    브랜드: 셀렙샵에디션
#    쇼핑몰: 네이버
#    링크: https://search.shopping.naver.com/catalog/50275941876
#
# 100. 온플 M12 여성 케이블 가디건 3종
#    최저가: 35,112원
#    브랜드:
#    쇼핑몰: 네이버
#    링크: https://search.shopping.naver.com/catalog/52686799333
